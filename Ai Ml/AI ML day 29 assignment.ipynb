# %%
import numpy as np

# %%
xAll = np.array(([2, 9], [1, 5], [3, 6], [5, 10]), dtype=float)  # input data
y = np.array(([92], [86], [89]), dtype=float) 

xAll = xAll / np.amax(xAll, axis=0)  # scaling input data
y = y / 100  # scaling output data (max test score is 100)

# split data
X = np.split(xAll, [3])[0]  # training data
xPredicted = np.split(xAll, [3])[1]  # testing data

y = np.array(([92], [86], [89]), dtype=float)
y = y / 100  # max test score is 100


class Neural_Network(object):
    def __init__(self):
        #parameters
        self.inputSize = 2
        self.outputSize = 1
        self.hiddenSize = 3

        #weights
        self.W1 = np.random.randn(
            self.inputSize,
            self.hiddenSize)  # (3x2) weight matrix from input to hidden layer
        self.W2 = np.random.randn(
            self.hiddenSize,
            self.outputSize)  # (3x1) weight matrix from hidden to output layer

    def forward(self, X):
        #forward propagation through our network
        self.z = np.dot(
            X,
            self.W1)  # dot product of X (input) and first set of 3x2 weights
        self.z2 = self.sigmoid(self.z)  # activation function
        self.z3 = np.dot(
            self.z2, self.W2
        )  # dot product of hidden layer (z2) and second set of 3x1 weights
        o = self.sigmoid(self.z3)  # final activation function
        return o

    def sigmoid(self, s):
        # activation function
        return 1 / (1 + np.exp(-s))

    def sigmoidPrime(self, s):
        #derivative of sigmoid
        return s * (1 - s)

    def backward(self, X, y, o):
        # backward propagate through the network
        self.o_error = y - o  # error in output
        self.o_delta = self.o_error * self.sigmoidPrime(
            o)  # applying derivative of sigmoid to error

        self.z2_error = self.o_delta.dot(
            self.W2.T
        )  # z2 error: how much our hidden layer weights contributed to output error
        self.z2_delta = self.z2_error * self.sigmoidPrime(
            self.z2)  # applying derivative of sigmoid to z2 error

        self.W1 += X.T.dot(
            self.z2_delta)  # adjusting first set (input --> hidden) weights
        self.W2 += self.z2.T.dot(
            self.o_delta)  # adjusting second set (hidden --> output) weights

    def train(self, X, y):
        o = self.forward(X)
        self.backward(X, y, o)

    def saveWeights(self):
        np.savetxt("w1.txt", self.W1, fmt="%s")
        np.savetxt("w2.txt", self.W2, fmt="%s")

    def predict(self):
        print("Predicted data based on trained weights: ")
        print("Input (scaled): \n" + str(xPredicted))
        print("Output: \n" + str(self.forward(xPredicted)))


NN = Neural_Network()
for i in range(1000):  # trains the NN 1,000 times
    print("# " + str(i) + "\n")
    print("Input (scaled): \n" + str(X))
    print("Actual Output: \n" + str(y))
    print("Predicted Output: \n" + str(NN.forward(X)))
    print("Loss: \n" +
          str(np.mean(np.square(y - NN.forward(X)))))  # mean sum squared loss
    print("\n")
    NN.train(X, y)

NN.saveWeights()
NN.predict()
# Out:
# # 0
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.18910371]
#  [0.22463462]
#  [0.21185911]]
# Loss:
# 0.4659245404806529
#
#
# # 1
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.26965956]
#  [0.30128676]
#  [0.29009671]]
# Loss:
# 0.3649957094742497
#
#
# # 2
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.37630367]
#  [0.39774954]
#  [0.38959934]]
# Loss:
# 0.25322733687707677
#
#
# # 3
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.48960257]
#  [0.49736494]
#  [0.49273586]]
# Loss:
# 0.15818831192964236
#
#
# # 4
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.58373918]
#  [0.57983097]
#  [0.5779828 ]]
# Loss:
# 0.09630692027819794
#
#
# # 5
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.65125937]
#  [0.63965218]
#  [0.63960274]]
# Loss:
# 0.06115782583429293
#
#
# # 6
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.69827477]
#  [0.68197272]
#  [0.68304403]]
# Loss:
# 0.04122885529586593
#
#
# # 7
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.73184264]
#  [0.71266226]
#  [0.71445481]]
# Loss:
# 0.02930923833817356
#
#
# # 8
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.75671453]
#  [0.73571929]
#  [0.73799823]]
# Loss:
# 0.02173745958241442
#
#
# # 9
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.77579617]
#  [0.75362353]
#  [0.75624519]]
# Loss:
# 0.016667015758817044
#
#
# # 10
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.79087464]
#  [0.76792062]
#  [0.77079294]]
# Loss:
# 0.013120764722841115
#
#
# # 11
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.80308473]
#  [0.77960414]
#  [0.78266563]]
# Loss:
# 0.010551113435563133
#
#
# # 12
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.81317394]
#  [0.78933585]
#  [0.79254387]]
# Loss:
# 0.008634309136867692
#
#
# # 13
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.821652  ]
#  [0.79757152]
#  [0.80089559]]
# Loss:
# 0.007169747101179507
#
#
# # 14
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.82887749]
#  [0.80463469]
#  [0.80805243]]
# Loss:
# 0.006028010978719828
#
#
# # 15
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.83510967]
#  [0.8107612 ]
#  [0.81425581]]
# Loss:
# 0.005122670323989983
#
#
# # 16
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84054048]
#  [0.81612699]
#  [0.8196856 ]]
# Loss:
# 0.004394257085955674
#
#
# # 17
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.84531509]
#  [0.82086602]
#  [0.82447862]]
# Loss:
# 0.0038007850523769215
#
#
# # 18
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8495453 ]
#  [0.82508214]
#  [0.82874082]]
# Loss:
# 0.0033119362905958834
#
#
# # 19
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85331864]
#  [0.82885713]
#  [0.83255556]]
# Loss:
# 0.002905381884880437
#
#
# # 20
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85670465]
#  [0.83225632]
#  [0.83598937]]
# Loss:
# 0.002564387408981935
#
#
# # 21
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.85975927]
#  [0.83533253]
#  [0.83909602]]
# Loss:
# 0.0022762153018683656
#
#
# # 22
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86252805]
#  [0.83812898]
#  [0.84191946]]
# Loss:
# 0.002031034998741771
#
#
# # 23
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86504847]
#  [0.8406814 ]
#  [0.84449599]]
# Loss:
# 0.0018211644741381622
#
#
# # 24
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86735165]
#  [0.84301957]
#  [0.84685588]]
# Loss:
# 0.001640532847368649
#
#
# # 25
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.86946367]
#  [0.84516855]
#  [0.84902455]]
# Loss:
# 0.001484293370514119
#
#
# # 26
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87140654]
#  [0.84714958]
#  [0.85102354]]
# Loss:
# 0.0013485405607606216
#
#
# # 27
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87319898]
#  [0.84898079]
#  [0.85287126]]
# Loss:
# 0.0012301006399359985
#
#
# # 28
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87485703]
#  [0.85067775]
#  [0.85458347]]
# Loss:
# 0.0011263743498511195
#
#
# # 29
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87639449]
#  [0.85225392]
#  [0.85617381]]
# Loss:
# 0.0010352177042936466
#
#
# # 30
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87782333]
#  [0.85372101]
#  [0.85765414]]
# Loss:
# 0.0009548505678144497
#
#
# # 31
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.87915398]
#  [0.85508922]
#  [0.85903479]]
# Loss:
# 0.0008837858848257273
#
#
# # 32
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88039554]
#  [0.85636754]
#  [0.86032483]]
# Loss:
# 0.0008207743996314024
#
#
# # 33
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88155605]
#  [0.85756387]
#  [0.86153227]]
# Loss:
# 0.0007647611141521297
#
#
# # 34
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88264258]
#  [0.85868521]
#  [0.86266419]]
# Loss:
# 0.0007148507228886604
#
#
# # 35
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88366141]
#  [0.85973778]
#  [0.86372686]]
# Loss:
# 0.0006702799739587831
#
#
# # 36
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88461812]
#  [0.86072713]
#  [0.8647259 ]]
# Loss:
# 0.0006303954174344365
#
#
# # 37
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8855177 ]
#  [0.86165823]
#  [0.86566633]]
# Loss:
# 0.0005946353762098618
#
#
# # 38
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88636463]
#  [0.86253554]
#  [0.86655264]]
# Loss:
# 0.0005625152502886449
#
#
# # 39
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88716291]
#  [0.86336309]
#  [0.8673889 ]]
# Loss:
# 0.0005336154704106091
#
#
# # 40
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88791618]
#  [0.86414449]
#  [0.86817876]]
# Loss:
# 0.0005075715707578369
#
#
# # 41
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8886277 ]
#  [0.86488304]
#  [0.86892555]]
# Loss:
# 0.0004840659668136481
#
#
# # 42
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88930044]
#  [0.86558172]
#  [0.86963227]]
# Loss:
# 0.00046282111310854204
#
#
# # 43
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.88993709]
#  [0.86624325]
#  [0.87030166]]
# Loss:
# 0.00044359378364692355
#
#
# # 44
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89054012]
#  [0.86687012]
#  [0.87093622]]
# Loss:
# 0.00042617027041295653
#
#
# # 45
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89111176]
#  [0.86746458]
#  [0.87153824]]
# Loss:
# 0.00041036233627811115
#
#
# # 46
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89165406]
#  [0.86802872]
#  [0.87210981]]
# Loss:
# 0.00039600379066714853
#
#
# # 47
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89216891]
#  [0.86856445]
#  [0.87265285]]
# Loss:
# 0.00038294758156211744
#
#
# # 48
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89265803]
#  [0.86907352]
#  [0.87316914]]
# Loss:
# 0.0003710633173950326
#
#
# # 49
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89312301]
#  [0.86955754]
#  [0.87366029]]
# Loss:
# 0.0003602351482768177
#
#
# # 50
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89356531]
#  [0.87001803]
#  [0.87412782]]
# Loss:
# 0.00035035994872885086
#
#
# # 51
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89398629]
#  [0.87045634]
#  [0.87457311]]
# Loss:
# 0.00034134575430830343
#
#
# # 52
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89438719]
#  [0.87087378]
#  [0.87499745]]
# Loss:
# 0.0003331104127771716
#
#
# # 53
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89476919]
#  [0.87127151]
#  [0.87540204]]
# Loss:
# 0.00032558041716479496
#
#
# # 54
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89513335]
#  [0.87165065]
#  [0.87578798]]
# Loss:
# 0.00031868989353235264
#
#
# # 55
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89548067]
#  [0.87201222]
#  [0.8761563 ]]
# Loss:
# 0.00031237972071317344
#
#
# # 56
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89581208]
#  [0.87235718]
#  [0.87650797]]
# Loss:
# 0.0003065967629700919
#
#
# # 57
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89612845]
#  [0.87268642]
#  [0.87684389]]
# Loss:
# 0.00030129319953407584
#
#
# # 58
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89643058]
#  [0.87300076]
#  [0.87716488]]
# Loss:
# 0.00029642593748945494
#
#
# # 59
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89671923]
#  [0.873301  ]
#  [0.87747173]]
# Loss:
# 0.0002919560965474396
#
#
# # 60
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89699511]
#  [0.87358785]
#  [0.87776517]]
# Loss:
# 0.0002878485559791551
#
#
# # 61
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89725888]
#  [0.87386201]
#  [0.87804589]]
# Loss:
# 0.00028407155542472254
#
#
# # 62
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89751115]
#  [0.8741241 ]
#  [0.87831453]]
# Loss:
# 0.00028059634250644734
#
#
# # 63
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8977525 ]
#  [0.87437474]
#  [0.87857169]]
# Loss:
# 0.00027739686119265084
#
#
# # 64
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89798348]
#  [0.87461448]
#  [0.87881794]]
# Loss:
# 0.0002744494757177212
#
#
# # 65
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89820461]
#  [0.87484386]
#  [0.87905382]]
# Loss:
# 0.00027173272558986223
#
#
# # 66
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89841635]
#  [0.87506338]
#  [0.87927982]]
# Loss:
# 0.00026922710783385006
#
#
# # 67
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89861918]
#  [0.8752735 ]
#  [0.87949642]]
# Loss:
# 0.00026691488313935677
#
#
# # 68
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8988135 ]
#  [0.87547469]
#  [0.87970407]]
# Loss:
# 0.0002647799030312772
#
#
# # 69
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89899973]
#  [0.87566734]
#  [0.87990319]]
# Loss:
# 0.00026280745555944004
#
#
# # 70
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89917825]
#  [0.87585187]
#  [0.88009417]]
# Loss:
# 0.0002609841273312305
#
#
# # 71
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89934942]
#  [0.87602864]
#  [0.88027739]]
# Loss:
# 0.0002592976799905277
#
#
# # 72
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89951357]
#  [0.87619802]
#  [0.8804532 ]]
# Loss:
# 0.000257736939487069
#
#
# # 73
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89967103]
#  [0.87636032]
#  [0.88062195]]
# Loss:
# 0.00025629169668790974
#
#
# # 74
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.8998221 ]
#  [0.87651589]
#  [0.88078395]]
# Loss:
# 0.00025495261806172487
#
#
# # 75
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.89996707]
#  [0.876665  ]
#  [0.8809395 ]]
# Loss:
# 0.0002537111653218944
#
#
# # 76
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90010621]
#  [0.87680796]
#  [0.88108889]]
# Loss:
# 0.0002525595230487761
#
#
# # 77
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90023977]
#  [0.87694503]
#  [0.88123239]]
# Loss:
# 0.00025149053342836793
#
#
# # 78
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90036802]
#  [0.87707647]
#  [0.88137025]]
# Loss:
# 0.0002504976373462598
#
#
# # 79
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90049117]
#  [0.87720252]
#  [0.88150273]]
# Loss:
# 0.000249574821164498
#
#
# # 80
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90060946]
#  [0.87732342]
#  [0.88163006]]
# Loss:
# 0.00024871656858637157
#
#
# # 81
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90072308]
#  [0.87743938]
#  [0.88175245]]
# Loss:
# 0.00024791781708191776
#
#
# # 82
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90083225]
#  [0.87755062]
#  [0.88187013]]
# Loss:
# 0.00024717391840630326
#
#
# # 83
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90093715]
#  [0.87765734]
#  [0.88198328]]
# Loss:
# 0.00024648060279542673
#
#
# # 84
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90103796]
#  [0.87775972]
#  [0.8820921 ]]
# Loss:
# 0.0002458339464688124
#
#
# # 85
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90113485]
#  [0.87785796]
#  [0.88219677]]
# Loss:
# 0.0002452303421103229
#
#
# # 86
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90122799]
#  [0.87795222]
#  [0.88229746]]
# Loss:
# 0.0002446664720326902
#
#
# # 87
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90131754]
#  [0.87804266]
#  [0.88239435]]
# Loss:
# 0.00024413928376338753
#
#
# # 88
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90140365]
#  [0.87812945]
#  [0.88248758]]
# Loss:
# 0.00024364596781701762
#
#
# # 89
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90148645]
#  [0.87821274]
#  [0.88257731]]
# Loss:
# 0.00024318393744411873
#
#
# # 90
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90156608]
#  [0.87829266]
#  [0.88266368]]
# Loss:
# 0.00024275081016802738
#
#
# # 91
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90164268]
#  [0.87836936]
#  [0.88274682]]
# Loss:
# 0.00024234439094078216
#
#
# # 92
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90171637]
#  [0.87844297]
#  [0.88282688]]
# Loss:
# 0.00024196265676634007
#
#
# # 93
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90178726]
#  [0.8785136 ]
#  [0.88290397]]
# Loss:
# 0.0002416037426546012
#
#
# # 94
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90185547]
#  [0.87858139]
#  [0.88297821]]
# Loss:
# 0.0002412659287834798
#
#
# # 95
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9019211 ]
#  [0.87864644]
#  [0.88304972]]
# Loss:
# 0.00024094762875833957
#
#
# # 96
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90198426]
#  [0.87870887]
#  [0.8831186 ]]
# Loss:
# 0.00024064737886910775
#
#
# # 97
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90204506]
#  [0.87876877]
#  [0.88318497]]
# Loss:
# 0.0002403638282549369
#
#
# # 98
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90210357]
#  [0.87882626]
#  [0.88324892]]
# Loss:
# 0.0002400957298951763
#
#
# # 99
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9021599 ]
#  [0.87888141]
#  [0.88331054]]
# Loss:
# 0.00023984193235305495
#
#
# # 100
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90221413]
#  [0.87893433]
#  [0.88336993]]
# Loss:
# 0.00023960137220558134
#
#
# # 101
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90226633]
#  [0.87898511]
#  [0.88342718]]
# Loss:
# 0.00023937306709934594
#
#
# # 102
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90231661]
#  [0.87903382]
#  [0.88348237]]
# Loss:
# 0.0002391561093776836
#
#
# # 103
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90236502]
#  [0.87908055]
#  [0.88353558]]
# Loss:
# 0.00023894966022957977
#
#
# # 104
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90241163]
#  [0.87912538]
#  [0.88358688]]
# Loss:
# 0.00023875294431538102
#
#
# # 105
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90245653]
#  [0.87916837]
#  [0.88363636]]
# Loss:
# 0.00023856524482849747
#
#
# # 106
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90249978]
#  [0.87920961]
#  [0.88368408]]
# Loss:
# 0.00023838589895588022
#
#
# # 107
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90254144]
#  [0.87924915]
#  [0.88373011]]
# Loss:
# 0.00023821429370356084
#
#
# # 108
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90258157]
#  [0.87928707]
#  [0.88377451]]
# Loss:
# 0.00023804986205649083
#
#
# # 109
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90262023]
#  [0.87932342]
#  [0.88381735]]
# Loss:
# 0.00023789207944462584
#
#
# # 110
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90265748]
#  [0.87935827]
#  [0.88385869]]
# Loss:
# 0.00023774046048977206
#
#
# # 111
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90269337]
#  [0.87939167]
#  [0.88389859]]
# Loss:
# 0.00023759455600992133
#
#
# # 112
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90272796]
#  [0.87942368]
#  [0.88393709]]
# Loss:
# 0.0002374539502597591
#
#
# # 113
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90276128]
#  [0.87945436]
#  [0.88397426]]
# Loss:
# 0.00023731825838803087
#
#
# # 114
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90279341]
#  [0.87948374]
#  [0.88401015]]
# Loss:
# 0.00023718712409393966
#
#
# # 115
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90282437]
#  [0.87951189]
#  [0.88404479]]
# Loss:
# 0.00023706021746651865
#
#
# # 116
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90285421]
#  [0.87953884]
#  [0.88407825]]
# Loss:
# 0.00023693723299199112
#
#
# # 117
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90288297]
#  [0.87956465]
#  [0.88411056]]
# Loss:
# 0.00023681788771568138
#
#
# # 118
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9029107 ]
#  [0.87958936]
#  [0.88414177]]
# Loss:
# 0.0002367019195460276
#
#
# # 119
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90293744]
#  [0.879613  ]
#  [0.88417192]]
# Loss:
# 0.0002365890856893001
#
#
# # 120
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90296322]
#  [0.87963562]
#  [0.88420105]]
# Loss:
# 0.00023647916120463273
#
#
# # 121
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90298807]
#  [0.87965727]
#  [0.8842292 ]]
# Loss:
# 0.00023637193766982428
#
#
# # 122
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90301204]
#  [0.87967796]
#  [0.88425641]]
# Loss:
# 0.00023626722194910769
#
#
# # 123
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90303516]
#  [0.87969774]
#  [0.8842827 ]]
# Loss:
# 0.00023616483505489567
#
#
# # 124
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90305745]
#  [0.87971665]
#  [0.88430812]]
# Loss:
# 0.0002360646110960848
#
#
# # 125
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90307895]
#  [0.87973471]
#  [0.8843327 ]]
# Loss:
# 0.00023596639630615735
#
#
# # 126
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90309969]
#  [0.87975196]
#  [0.88435646]]
# Loss:
# 0.00023587004814485096
#
#
# # 127
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9031197 ]
#  [0.87976843]
#  [0.88437944]]
# Loss:
# 0.00023577543446768692
#
#
# # 128
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.903139  ]
#  [0.87978415]
#  [0.88440168]]
# Loss:
# 0.00023568243275806885
#
#
# # 129
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90315762]
#  [0.87979914]
#  [0.88442318]]
# Loss:
# 0.0002355909294171314
#
#
# # 130
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90317559]
#  [0.87981344]
#  [0.884444  ]]
# Loss:
# 0.0002355008191068967
#
#
# # 131
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90319292]
#  [0.87982706]
#  [0.88446413]]
# Loss:
# 0.00023541200414261274
#
#
# # 132
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90320965]
#  [0.87984004]
#  [0.88448363]]
# Loss:
# 0.00023532439393052166
#
#
# # 133
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9032258 ]
#  [0.87985239]
#  [0.8845025 ]]
# Loss:
# 0.00023523790444759832
#
#
# # 134
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90324139]
#  [0.87986415]
#  [0.88452077]]
# Loss:
# 0.00023515245776001671
#
#
# # 135
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90325643]
#  [0.87987532]
#  [0.88453847]]
# Loss:
# 0.00023506798157744537
#
#
# # 136
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90327095]
#  [0.87988594]
#  [0.88455561]]
# Loss:
# 0.00023498440884041336
#
#
# # 137
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90328497]
#  [0.87989603]
#  [0.88457221]]
# Loss:
# 0.0002349016773382679
#
#
# # 138
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90329851]
#  [0.8799056 ]
#  [0.8845883 ]]
# Loss:
# 0.00023481972935539427
#
#
# # 139
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90331158]
#  [0.87991467]
#  [0.88460389]]
# Loss:
# 0.0002347385113435971
#
#
# # 140
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9033242 ]
#  [0.87992327]
#  [0.884619  ]]
# Loss:
# 0.00023465797361863858
#
#
# # 141
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90333639]
#  [0.8799314 ]
#  [0.88463366]]
# Loss:
# 0.00023457807007912535
#
#
# # 142
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90334816]
#  [0.87993909]
#  [0.88464786]]
# Loss:
# 0.00023449875794610974
#
#
# # 143
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90335954]
#  [0.87994635]
#  [0.88466165]]
# Loss:
# 0.00023441999752180898
#
#
# # 144
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90337052]
#  [0.8799532 ]
#  [0.88467502]]
# Loss:
# 0.0002343417519660206
#
#
# # 145
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90338114]
#  [0.87995966]
#  [0.88468799]]
# Loss:
# 0.00023426398708896728
#
#
# # 146
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9033914 ]
#  [0.87996573]
#  [0.88470058]]
# Loss:
# 0.00023418667115925515
#
#
# # 147
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90340131]
#  [0.87997144]
#  [0.8847128 ]]
# Loss:
# 0.0002341097747259319
#
#
# # 148
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90341089]
#  [0.87997679]
#  [0.88472467]]
# Loss:
# 0.00023403327045350524
#
#
# # 149
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90342015]
#  [0.8799818 ]
#  [0.8847362 ]]
# Loss:
# 0.00023395713296902148
#
#
# # 150
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9034291 ]
#  [0.87998648]
#  [0.88474739]]
# Loss:
# 0.00023388133872027982
#
#
# # 151
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90343775]
#  [0.87999084]
#  [0.88475827]]
# Loss:
# 0.00023380586584439742
#
#
# # 152
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90344612]
#  [0.8799949 ]
#  [0.88476885]]
# Loss:
# 0.00023373069404590704
#
#
# # 153
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90345421]
#  [0.87999867]
#  [0.88477913]]
# Loss:
# 0.00023365580448373756
#
#
# # 154
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90346203]
#  [0.88000215]
#  [0.88478912]]
# Loss:
# 0.0002335811796664019
#
#
# # 155
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9034696 ]
#  [0.88000536]
#  [0.88479885]]
# Loss:
# 0.00023350680335479306
#
#
# # 156
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90347693]
#  [0.88000831]
#  [0.8848083 ]]
# Loss:
# 0.0002334326604720061
#
#
# # 157
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90348401]
#  [0.880011  ]
#  [0.88481751]]
# Loss:
# 0.00023335873701973907
#
#
# # 158
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90349087]
#  [0.88001345]
#  [0.88482647]]
# Loss:
# 0.0002332850200007035
#
#
# # 159
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9034975 ]
#  [0.88001567]
#  [0.8848352 ]]
# Loss:
# 0.00023321149734666644
#
#
# # 160
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90350393]
#  [0.88001766]
#  [0.88484369]]
# Loss:
# 0.0002331381578517095
#
#
# # 161
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90351014]
#  [0.88001943]
#  [0.88485197]]
# Loss:
# 0.00023306499111028014
#
#
# # 162
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90351616]
#  [0.88002099]
#  [0.88486004]]
# Loss:
# 0.0002329919874597313
#
#
# # 163
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.903522  ]
#  [0.88002235]
#  [0.88486791]]
# Loss:
# 0.00023291913792702952
#
#
# # 164
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90352764]
#  [0.88002351]
#  [0.88487558]]
# Loss:
# 0.00023284643417925276
#
#
# # 165
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90353311]
#  [0.88002449]
#  [0.88488306]]
# Loss:
# 0.00023277386847771284
#
#
# # 166
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90353841]
#  [0.88002528]
#  [0.88489035]]
# Loss:
# 0.0002327014336353439
#
#
# # 167
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90354355]
#  [0.8800259 ]
#  [0.88489748]]
# Loss:
# 0.00023262912297717902
#
#
# # 168
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90354853]
#  [0.88002636]
#  [0.88490443]]
# Loss:
# 0.0002325569303036596
#
#
# # 169
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90355335]
#  [0.88002665]
#  [0.88491122]]
# Loss:
# 0.00023248484985658976
#
#
# # 170
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90355803]
#  [0.88002679]
#  [0.88491786]]
# Loss:
# 0.00023241287628754953
#
#
# # 171
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90356257]
#  [0.88002677]
#  [0.88492434]]
# Loss:
# 0.0002323410046285306
#
#
# # 172
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90356697]
#  [0.88002661]
#  [0.88493068]]
# Loss:
# 0.00023226923026475587
#
#
# # 173
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90357124]
#  [0.88002632]
#  [0.88493688]]
# Loss:
# 0.0002321975489093848
#
#
# # 174
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90357539]
#  [0.88002588]
#  [0.88494294]]
# Loss:
# 0.00023212595658007016
#
#
# # 175
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90357941]
#  [0.88002532]
#  [0.88494887]]
# Loss:
# 0.00023205444957717745
#
#
# # 176
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90358331]
#  [0.88002464]
#  [0.88495467]]
# Loss:
# 0.0002319830244635798
#
#
# # 177
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9035871 ]
#  [0.88002383]
#  [0.88496036]]
# Loss:
# 0.00023191167804589329
#
#
# # 178
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90359078]
#  [0.88002291]
#  [0.88496592]]
# Loss:
# 0.00023184040735706461
#
#
# # 179
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90359436]
#  [0.88002188]
#  [0.88497138]]
# Loss:
# 0.00023176920964018872
#
#
# # 180
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90359784]
#  [0.88002074]
#  [0.88497672]]
# Loss:
# 0.00023169808233351253
#
#
# # 181
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90360121]
#  [0.8800195 ]
#  [0.88498196]]
# Loss:
# 0.0002316270230564864
#
#
# # 182
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036045 ]
#  [0.88001815]
#  [0.8849871 ]]
# Loss:
# 0.00023155602959682085
#
#
# # 183
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90360769]
#  [0.88001671]
#  [0.88499215]]
# Loss:
# 0.0002314850998984929
#
#
# # 184
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036108 ]
#  [0.88001518]
#  [0.88499709]]
# Loss:
# 0.00023141423205056872
#
#
# # 185
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90361382]
#  [0.88001356]
#  [0.88500195]]
# Loss:
# 0.00023134342427685167
#
#
# # 186
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90361676]
#  [0.88001186]
#  [0.88500672]]
# Loss:
# 0.00023127267492628156
#
#
# # 187
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90361962]
#  [0.88001007]
#  [0.88501141]]
# Loss:
# 0.00023120198246398167
#
#
# # 188
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036224 ]
#  [0.8800082 ]
#  [0.88501602]]
# Loss:
# 0.00023113134546298567
#
#
# # 189
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90362512]
#  [0.88000626]
#  [0.88502055]]
# Loss:
# 0.00023106076259653125
#
#
# # 190
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90362776]
#  [0.88000424]
#  [0.885025  ]]
# Loss:
# 0.0002309902326309137
#
#
# # 191
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363033]
#  [0.88000216]
#  [0.88502938]]
# Loss:
# 0.00023091975441884695
#
#
# # 192
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363284]
#  [0.88      ]
#  [0.88503369]]
# Loss:
# 0.00023084932689329855
#
#
# # 193
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363529]
#  [0.87999778]
#  [0.88503793]]
# Loss:
# 0.00023077894906176112
#
#
# # 194
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90363768]
#  [0.87999549]
#  [0.88504211]]
# Loss:
# 0.0002307086200009522
#
#
# # 195
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90364001]
#  [0.87999314]
#  [0.88504622]]
# Loss:
# 0.0002306383388518634
#
#
# # 196
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90364228]
#  [0.87999074]
#  [0.88505028]]
# Loss:
# 0.00023056810481517944
#
#
# # 197
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036445 ]
#  [0.87998828]
#  [0.88505427]]
# Loss:
# 0.00023049791714702185
#
#
# # 198
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90364667]
#  [0.87998576]
#  [0.88505821]]
# Loss:
# 0.0002304277751549968
#
#
# # 199
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90364878]
#  [0.87998319]
#  [0.8850621 ]]
# Loss:
# 0.0002303576781945311
#
#
# # 200
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365085]
#  [0.87998057]
#  [0.88506593]]
# Loss:
# 0.00023028762566544328
#
#
# # 201
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365287]
#  [0.8799779 ]
#  [0.88506971]]
# Loss:
# 0.0002302176170088058
#
#
# # 202
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365485]
#  [0.87997518]
#  [0.88507345]]
# Loss:
# 0.00023014765170397227
#
#
# # 203
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365678]
#  [0.87997242]
#  [0.88507714]]
# Loss:
# 0.00023007772926587195
#
#
# # 204
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90365867]
#  [0.87996962]
#  [0.88508078]]
# Loss:
# 0.00023000784924246816
#
#
# # 205
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366052]
#  [0.87996677]
#  [0.88508438]]
# Loss:
# 0.00022993801121239482
#
#
# # 206
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366233]
#  [0.87996389]
#  [0.88508793]]
# Loss:
# 0.0002298682147827736
#
#
# # 207
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036641 ]
#  [0.87996096]
#  [0.88509145]]
# Loss:
# 0.0002297984595871895
#
#
# # 208
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366584]
#  [0.879958  ]
#  [0.88509493]]
# Loss:
# 0.00022972874528378687
#
#
# # 209
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366755]
#  [0.879955  ]
#  [0.88509837]]
# Loss:
# 0.00022965907155354196
#
#
# # 210
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90366921]
#  [0.87995197]
#  [0.88510177]]
# Loss:
# 0.00022958943809861236
#
#
# # 211
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90367085]
#  [0.8799489 ]
#  [0.88510514]]
# Loss:
# 0.00022951984464083638
#
#
# # 212
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90367246]
#  [0.87994581]
#  [0.88510847]]
# Loss:
# 0.00022945029092033832
#
#
# # 213
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90367403]
#  [0.87994268]
#  [0.88511177]]
# Loss:
# 0.0002293807766942038
#
#
# # 214
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90367558]
#  [0.87993952]
#  [0.88511504]]
# Loss:
# 0.00022931130173528614
#
#
# # 215
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036771 ]
#  [0.87993633]
#  [0.88511828]]
# Loss:
# 0.00022924186583107834
#
#
# # 216
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90367859]
#  [0.87993312]
#  [0.88512149]]
# Loss:
# 0.0002291724687826613
#
#
# # 217
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368006]
#  [0.87992988]
#  [0.88512467]]
# Loss:
# 0.0002291031104037491
#
#
# # 218
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036815 ]
#  [0.87992661]
#  [0.88512783]]
# Loss:
# 0.00022903379051976655
#
#
# # 219
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368292]
#  [0.87992332]
#  [0.88513095]]
# Loss:
# 0.00022896450896704162
#
#
# # 220
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368431]
#  [0.87992001]
#  [0.88513406]]
# Loss:
# 0.00022889526559199987
#
#
# # 221
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368568]
#  [0.87991667]
#  [0.88513713]]
# Loss:
# 0.00022882606025045914
#
#
# # 222
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368703]
#  [0.87991331]
#  [0.88514019]]
# Loss:
# 0.00022875689280695794
#
#
# # 223
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368836]
#  [0.87990993]
#  [0.88514322]]
# Loss:
# 0.00022868776313413186
#
#
# # 224
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90368967]
#  [0.87990653]
#  [0.88514623]]
# Loss:
# 0.00022861867111212959
#
#
# # 225
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369096]
#  [0.87990311]
#  [0.88514922]]
# Loss:
# 0.00022854961662808666
#
#
# # 226
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369223]
#  [0.87989968]
#  [0.88515219]]
# Loss:
# 0.00022848059957562044
#
#
# # 227
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369348]
#  [0.87989622]
#  [0.88515513]]
# Loss:
# 0.00022841161985437167
#
#
# # 228
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369472]
#  [0.87989275]
#  [0.88515806]]
# Loss:
# 0.00022834267736956696
#
#
# # 229
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369594]
#  [0.87988926]
#  [0.88516097]]
# Loss:
# 0.00022827377203162914
#
#
# # 230
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369714]
#  [0.87988575]
#  [0.88516387]]
# Loss:
# 0.00022820490375579497
#
#
# # 231
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90369833]
#  [0.87988223]
#  [0.88516674]]
# Loss:
# 0.00022813607246178404
#
#
# # 232
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9036995]
#  [0.8798787]
#  [0.8851696]]
# Loss:
# 0.00022806727807347046
#
#
# # 233
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370066]
#  [0.87987515]
#  [0.88517245]]
# Loss:
# 0.00022799852051858796
#
#
# # 234
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9037018 ]
#  [0.87987159]
#  [0.88517527]]
# Loss:
# 0.0002279297997284561
#
#
# # 235
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370293]
#  [0.87986801]
#  [0.88517809]]
# Loss:
# 0.00022786111563771465
#
#
# # 236
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370405]
#  [0.87986443]
#  [0.88518089]]
# Loss:
# 0.0002277924681841118
#
#
# # 237
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370515]
#  [0.87986083]
#  [0.88518367]]
# Loss:
# 0.0002277238573082397
#
#
# # 238
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370625]
#  [0.87985722]
#  [0.88518644]]
# Loss:
# 0.00022765528295337804
#
#
# # 239
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370733]
#  [0.8798536 ]
#  [0.8851892 ]]
# Loss:
# 0.00022758674506526374
#
#
# # 240
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9037084 ]
#  [0.87984996]
#  [0.88519194]]
# Loss:
# 0.0002275182435919405
#
#
# # 241
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90370946]
#  [0.87984632]
#  [0.88519468]]
# Loss:
# 0.00022744977848358216
#
#
# # 242
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371051]
#  [0.87984267]
#  [0.8851974 ]]
# Loss:
# 0.00022738134969233986
#
#
# # 243
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371155]
#  [0.87983901]
#  [0.88520011]]
# Loss:
# 0.00022731295717221442
#
#
# # 244
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371258]
#  [0.87983534]
#  [0.88520281]]
# Loss:
# 0.00022724460087890084
#
#
# # 245
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9037136 ]
#  [0.87983166]
#  [0.8852055 ]]
# Loss:
# 0.00022717628076968077
#
#
# # 246
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371461]
#  [0.87982797]
#  [0.88520818]]
# Loss:
# 0.00022710799680332157
#
#
# # 247
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371561]
#  [0.87982428]
#  [0.88521085]]
# Loss:
# 0.00022703974893994942
#
#
# # 248
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371661]
#  [0.87982057]
#  [0.88521351]]
# Loss:
# 0.00022697153714095465
#
#
# # 249
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90371759]
#  [0.87981686]
#  [0.88521616]]
# Loss:
# 0.0002269033613689096
#
#
# ...
#  [0.89]]
# Predicted Output:
# [[0.90422502]
#  [0.87747134]
#  [0.88669285]]
# Loss:
# 0.00018834497784664395
#
#
# # 918
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422575]
#  [0.8774682 ]
#  [0.88669484]]
# Loss:
# 0.00018829631655035596
#
#
# # 919
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422648]
#  [0.87746506]
#  [0.88669684]]
# Loss:
# 0.00018824767860077277
#
#
# # 920
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422721]
#  [0.87746192]
#  [0.88669883]]
# Loss:
# 0.0001881990639828837
#
#
# # 921
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422794]
#  [0.87745878]
#  [0.88670082]]
# Loss:
# 0.00018815047268169751
#
#
# # 922
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422867]
#  [0.87745564]
#  [0.88670281]]
# Loss:
# 0.00018810190468221841
#
#
# # 923
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90422939]
#  [0.8774525 ]
#  [0.8867048 ]]
# Loss:
# 0.00018805335996947318
#
#
# # 924
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423012]
#  [0.87744936]
#  [0.88670679]]
# Loss:
# 0.00018800483852849273
#
#
# # 925
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423085]
#  [0.87744623]
#  [0.88670877]]
# Loss:
# 0.00018795634034431886
#
#
# # 926
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423158]
#  [0.87744309]
#  [0.88671076]]
# Loss:
# 0.00018790786540199555
#
#
# # 927
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423231]
#  [0.87743996]
#  [0.88671275]]
# Loss:
# 0.00018785941368659279
#
#
# # 928
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423304]
#  [0.87743682]
#  [0.88671474]]
# Loss:
# 0.00018781098518317458
#
#
# # 929
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423376]
#  [0.87743369]
#  [0.88671672]]
# Loss:
# 0.0001877625798768211
#
#
# # 930
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423449]
#  [0.87743056]
#  [0.88671871]]
# Loss:
# 0.0001877141977526215
#
#
# # 931
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423522]
#  [0.87742743]
#  [0.88672069]]
# Loss:
# 0.0001876658387956749
#
#
# # 932
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423595]
#  [0.8774243 ]
#  [0.88672268]]
# Loss:
# 0.00018761750299108962
#
#
# # 933
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423668]
#  [0.87742117]
#  [0.88672466]]
# Loss:
# 0.00018756919032397962
#
#
# # 934
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042374 ]
#  [0.87741805]
#  [0.88672664]]
# Loss:
# 0.000187520900779482
#
#
# # 935
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423813]
#  [0.87741492]
#  [0.88672862]]
# Loss:
# 0.00018747263434272337
#
#
# # 936
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423886]
#  [0.8774118 ]
#  [0.88673061]]
# Loss:
# 0.00018742439099885696
#
#
# # 937
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90423959]
#  [0.87740867]
#  [0.88673259]]
# Loss:
# 0.00018737617073303616
#
#
# # 938
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424031]
#  [0.87740555]
#  [0.88673457]]
# Loss:
# 0.00018732797353042578
#
#
# # 939
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424104]
#  [0.87740243]
#  [0.88673655]]
# Loss:
# 0.0001872797993762056
#
#
# # 940
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424177]
#  [0.87739931]
#  [0.88673853]]
# Loss:
# 0.0001872316482555567
#
#
# # 941
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042425 ]
#  [0.87739619]
#  [0.88674051]]
# Loss:
# 0.00018718352015367125
#
#
# # 942
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424322]
#  [0.87739307]
#  [0.88674248]]
# Loss:
# 0.00018713541505575477
#
#
# # 943
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424395]
#  [0.87738995]
#  [0.88674446]]
# Loss:
# 0.00018708733294702675
#
#
# # 944
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424468]
#  [0.87738683]
#  [0.88674644]]
# Loss:
# 0.00018703927381270185
#
#
# # 945
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424541]
#  [0.87738372]
#  [0.88674842]]
# Loss:
# 0.00018699123763801534
#
#
# # 946
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424613]
#  [0.8773806 ]
#  [0.88675039]]
# Loss:
# 0.00018694322440821167
#
#
# # 947
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424686]
#  [0.87737749]
#  [0.88675237]]
# Loss:
# 0.0001868952341085401
#
#
# # 948
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424759]
#  [0.87737438]
#  [0.88675434]]
# Loss:
# 0.00018684726672426393
#
#
# # 949
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424831]
#  [0.87737127]
#  [0.88675632]]
# Loss:
# 0.00018679932224065015
#
#
# # 950
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424904]
#  [0.87736815]
#  [0.88675829]]
# Loss:
# 0.00018675140064297797
#
#
# # 951
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90424977]
#  [0.87736504]
#  [0.88676026]]
# Loss:
# 0.00018670350191654398
#
#
# # 952
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425049]
#  [0.87736194]
#  [0.88676223]]
# Loss:
# 0.00018665562604664018
#
#
# # 953
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425122]
#  [0.87735883]
#  [0.88676421]]
# Loss:
# 0.00018660777301857885
#
#
# # 954
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425195]
#  [0.87735572]
#  [0.88676618]]
# Loss:
# 0.0001865599428176744
#
#
# # 955
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425267]
#  [0.87735262]
#  [0.88676815]]
# Loss:
# 0.0001865121354292596
#
#
# # 956
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.9042534 ]
#  [0.87734951]
#  [0.88677012]]
# Loss:
# 0.00018646435083866466
#
#
# # 957
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425413]
#  [0.87734641]
#  [0.88677209]]
# Loss:
# 0.0001864165890312438
#
#
# # 958
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425485]
#  [0.8773433 ]
#  [0.88677406]]
# Loss:
# 0.0001863688499923466
#
#
# # 959
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425558]
#  [0.8773402 ]
#  [0.88677603]]
# Loss:
# 0.00018632113370734067
#
#
# # 960
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425631]
#  [0.8773371 ]
#  [0.88677799]]
# Loss:
# 0.0001862734401615988
#
#
# # 961
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425703]
#  [0.877334  ]
#  [0.88677996]]
# Loss:
# 0.00018622576934050728
#
#
# # 962
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425776]
#  [0.8773309 ]
#  [0.88678193]]
# Loss:
# 0.00018617812122945966
#
#
# # 963
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425848]
#  [0.87732781]
#  [0.88678389]]
# Loss:
# 0.00018613049581386247
#
#
# # 964
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425921]
#  [0.87732471]
#  [0.88678586]]
# Loss:
# 0.00018608289307911916
#
#
# # 965
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90425994]
#  [0.87732161]
#  [0.88678782]]
# Loss:
# 0.0001860353130106583
#
#
# # 966
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426066]
#  [0.87731852]
#  [0.88678979]]
# Loss:
# 0.0001859877555939101
#
#
# # 967
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426139]
#  [0.87731542]
#  [0.88679175]]
# Loss:
# 0.00018594022081431385
#
#
# # 968
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426211]
#  [0.87731233]
#  [0.88679372]]
# Loss:
# 0.0001858927086573199
#
#
# # 969
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426284]
#  [0.87730924]
#  [0.88679568]]
# Loss:
# 0.0001858452191083901
#
#
# # 970
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426357]
#  [0.87730615]
#  [0.88679764]]
# Loss:
# 0.00018579775215298963
#
#
# # 971
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426429]
#  [0.87730306]
#  [0.8867996 ]]
# Loss:
# 0.00018575030777660047
#
#
# # 972
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426502]
#  [0.87729997]
#  [0.88680156]]
# Loss:
# 0.00018570288596470724
#
#
# # 973
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426574]
#  [0.87729688]
#  [0.88680352]]
# Loss:
# 0.0001856554867028079
#
#
# # 974
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426647]
#  [0.87729379]
#  [0.88680548]]
# Loss:
# 0.00018560810997641123
#
#
# # 975
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426719]
#  [0.87729071]
#  [0.88680744]]
# Loss:
# 0.0001855607557710265
#
#
# # 976
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426792]
#  [0.87728762]
#  [0.8868094 ]]
# Loss:
# 0.00018551342407218869
#
#
# # 977
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426864]
#  [0.87728454]
#  [0.88681136]]
# Loss:
# 0.0001854661148654245
#
#
# # 978
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90426937]
#  [0.87728146]
#  [0.88681332]]
# Loss:
# 0.0001854188281362807
#
#
# # 979
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427009]
#  [0.87727837]
#  [0.88681527]]
# Loss:
# 0.0001853715638703083
#
#
# # 980
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427082]
#  [0.87727529]
#  [0.88681723]]
# Loss:
# 0.00018532432205307283
#
#
# # 981
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427154]
#  [0.87727221]
#  [0.88681918]]
# Loss:
# 0.00018527710267014197
#
#
# # 982
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427227]
#  [0.87726913]
#  [0.88682114]]
# Loss:
# 0.0001852299057071016
#
#
# # 983
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427299]
#  [0.87726606]
#  [0.88682309]]
# Loss:
# 0.0001851827311495386
#
#
# # 984
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427372]
#  [0.87726298]
#  [0.88682505]]
# Loss:
# 0.00018513557898305465
#
#
# # 985
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427444]
#  [0.8772599 ]
#  [0.886827  ]]
# Loss:
# 0.00018508844919325914
#
#
# # 986
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427517]
#  [0.87725683]
#  [0.88682895]]
# Loss:
# 0.00018504134176577016
#
#
# # 987
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427589]
#  [0.87725375]
#  [0.88683091]]
# Loss:
# 0.00018499425668621488
#
#
# # 988
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427662]
#  [0.87725068]
#  [0.88683286]]
# Loss:
# 0.0001849471939402301
#
#
# # 989
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427734]
#  [0.87724761]
#  [0.88683481]]
# Loss:
# 0.00018490015351346287
#
#
# # 990
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427807]
#  [0.87724454]
#  [0.88683676]]
# Loss:
# 0.0001848531353915674
#
#
# # 991
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427879]
#  [0.87724147]
#  [0.88683871]]
# Loss:
# 0.00018480613956021032
#
#
# # 992
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90427951]
#  [0.8772384 ]
#  [0.88684066]]
# Loss:
# 0.00018475916600506692
#
#
# # 993
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428024]
#  [0.87723533]
#  [0.88684261]]
# Loss:
# 0.00018471221471181795
#
#
# # 994
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428096]
#  [0.87723226]
#  [0.88684456]]
# Loss:
# 0.00018466528566615532
#
#
# # 995
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428169]
#  [0.8772292 ]
#  [0.8868465 ]]
# Loss:
# 0.00018461837885378244
#
#
# # 996
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428241]
#  [0.87722613]
#  [0.88684845]]
# Loss:
# 0.0001845714942604133
#
#
# # 997
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428313]
#  [0.87722307]
#  [0.8868504 ]]
# Loss:
# 0.00018452463187176418
#
#
# # 998
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428386]
#  [0.87722   ]
#  [0.88685234]]
# Loss:
# 0.00018447779167356595
#
#
# # 999
#
# Input (scaled):
# [[0.4 0.9]
#  [0.2 0.5]
#  [0.6 0.6]]
# Actual Output:
# [[0.92]
#  [0.86]
#  [0.89]]
# Predicted Output:
# [[0.90428458]
#  [0.87721694]
#  [0.88685429]]
# Loss:
# 0.00018443097365155605
#
#
# Predicted data based on trained weights:
# Input (scaled):
# [[1. 1.]]
# Output:
# [[0.90394788]]
